# %% [markdown]
# # <img src="./resources/GA.png" width="25" height="25" /> <span style="color:Blue">DSI Capstone:  MTB Trail Recommender Engine</span>
# ---
# ## <span style="color:Green">EDA</span>
#
# #### Ryan McDonald -General Assembly
#
#
#
# ---

# %% [markdown]
# ### Notebook Contents:
#
# - [Reading the User Data](#intro)
#     - [Arizona User Data Cleaning](#cleanaz)
#     - [Utah User Data Cleaning](#cleanut)
# - [Reading the Trail Data](#trail)
#     - [Arizona Trail Data Cleaning](#trailaz)
#         - [Arizona Imputation/OHE](#imputeaz)
#     - [Utah Trail Data Cleaning](#trailut)
#         - [Utah Imputation/OHE](#imputeut)
# - [Export to CSV- Arizona Trails](#saveaz)
# - [Export to CSV- Utah Trails](#saveut)

# %% [markdown]
# **Imports**

# %%
# general processing, CSV manipulation
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# <a id='intro'></a>
# ## 1. Read Data- Arizona and Utah Trail Data

# %%
ut_trails = pd.read_csv('./data/trail_dashboard/ut_trails.csv')
ut_trails.head()
# Out:
#                       trail_name  length              difficulty  \
# 0  Thunder Mountain Trail #33098     8.1  INTERMEDIATE/DIFFICULT
# 1                  Wasatch Crest    12.5  INTERMEDIATE/DIFFICULT
# 2                   Captain Ahab     4.2               DIFFICULT
# 3                 Wire Mesa Loop     7.4  INTERMEDIATE/DIFFICULT
# 4                       Ramblin'     3.3  INTERMEDIATE/DIFFICULT
#
#                                           trail_link        city  popularity  \
# 0  https://www.mtbproject.com/trail/1868735/thund...   Panguitch    1.000000
# 1  https://www.mtbproject.com/trail/3654027/wasat...        Alta    0.998922
# 2  https://www.mtbproject.com/trail/648766/captai...        Moab    0.997845
# 3  https://www.mtbproject.com/trail/7021693/wire-...  Springdale    0.996767
# 4   https://www.mtbproject.com/trail/7000569/ramblin        Moab    0.995690
#
#    rating                              local_club  \
# 0     4.7  Trail Alliance of Southern Utah (TASU)
# 1     4.8                                     NaN
# 2     4.7                                     NaN
# 3     4.6                                     NaN
# 4     4.7                                     NaN
#
#                                      local_club_site  \
# 0  https://www.mtbproject.com/club/31800/trail-al...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                           land_manager             land_manager_site  \
# 0  USFS - Dixie National Forest Office  http://www.fs.usda.gov/dixie
# 1                                  NaN                           NaN
# 2                                  NaN                           NaN
# 3                                  NaN                           NaN
# 4                                  NaN                           NaN
#
#    tot_climb  tot_descent  ave_grade  max_grade  max_elevation  min_elevation  \
# 0      689.0       1681.0        6.0       27.0         8263.0         7084.0
# 1     1084.0       2656.0        6.0       26.0         9882.0         7616.0
# 2      326.0        981.0        6.0       23.0         4898.0         4034.0
# 3      428.0        415.0        2.0       12.0         4502.0         4326.0
# 4      195.0        398.0        3.0       12.0         5279.0         4971.0
#
#   dog_policy e_bike_policy
# 0  Off-leash       Unknown
# 1    No Dogs   Not Allowed
# 2    Leashed   Not Allowed
# 3    Unknown       Allowed
# 4    Leashed   Not Allowed

# %%
az_trails = pd.read_csv('./data/trail_dashboard/az_trails.csv')
az_trails.head()
# Out:
#                 trail_name  length              difficulty  \
# 0             Hiline Trail     3.1          VERY DIFFICULT
# 1         Slim Shady Trail     2.6  INTERMEDIATE/DIFFICULT
# 2                   Mescal     2.4  INTERMEDIATE/DIFFICULT
# 3               Chuckwagon     5.4            INTERMEDIATE
# 4  Tortolita Preserve Loop     9.7            INTERMEDIATE
#
#                                           trail_link  \
# 0  https://www.mtbproject.com/trail/593534/hiline...
# 1  https://www.mtbproject.com/trail/593708/slim-s...
# 2    https://www.mtbproject.com/trail/4960011/mescal
# 3  https://www.mtbproject.com/trail/4960774/chuck...
# 4  https://www.mtbproject.com/trail/6390787/torto...
#
#                               city  popularity  rating  \
# 0  Village of Oak Creek (Big Park)    1.000000     4.7
# 1  Village of Oak Creek (Big Park)    0.998953     4.4
# 2                      West Sedona    0.997906     4.6
# 3                      West Sedona    0.996859     4.5
# 4                        Tortolita    0.995812     4.2
#
#                            local_club  \
# 0     Verde Valley Cyclists Coalition
# 1     Verde Valley Cyclists Coalition
# 2     Verde Valley Cyclists Coalition
# 3     Verde Valley Cyclists Coalition
# 4  Sonoran Desert Mountain Bicyclists
#
#                                      local_club_site  \
# 0  https://www.mtbproject.com/club/4920204/verde-...
# 1  https://www.mtbproject.com/club/4920204/verde-...
# 2  https://www.mtbproject.com/club/4920204/verde-...
# 3  https://www.mtbproject.com/club/4920204/verde-...
# 4  https://www.mtbproject.com/club/112648/sonoran...
#
#                                         land_manager  \
# 0             USFS - Coconino National Forest Office
# 1             USFS - Coconino National Forest Office
# 2             USFS - Coconino National Forest Office
# 3             USFS - Coconino National Forest Office
# 4  Pima County - Natural Resources, Parks and Rec...
#
#                                    land_manager_site  tot_climb  tot_descent  \
# 0                    http://www.fs.usda.gov/coconino      326.0        695.0
# 1                    http://www.fs.usda.gov/coconino      265.0        264.0
# 2                    http://www.fs.usda.gov/coconino      206.0        166.0
# 3                    http://www.fs.usda.gov/coconino      559.0        489.0
# 4  http://webcms.pima.gov/government/natural_reso...      520.0        520.0
#
#    ave_grade  max_grade  max_elevation  min_elevation dog_policy e_bike_policy
# 0        6.0       35.0         4646.0         4086.0    Unknown       Unknown
# 1        4.0       11.0         4464.0         4202.0    Unknown       Unknown
# 2        3.0       11.0         4710.0         4520.0    Unknown       Unknown
# 3        4.0       13.0         4679.0         4499.0    Unknown       Unknown
# 4        2.0        4.0         2804.0         2326.0    Unknown       Unknown

# %%
plt.figure(figsize = (8, 5))
sns.countplot(x='difficulty', data= az_trails,
              order=['EASY', 'EASY/INTERMEDIATE', 'INTERMEDIATE', 
                     'INTERMEDIATE/DIFFICULT', 'DIFFICULT', 
                     'VERY DIFFICULT'] )
plt.title('AZ Trail Difficulty Distribution', size = 16)
plt.ylabel('Count', size = 14)
plt.xlabel('Difficulty', size = 14)
plt.xticks(rotation = 90)

plt.show()

# %%
plt.figure(figsize = (8, 5))
sns.countplot(x='difficulty', data= ut_trails, 
              order=['EASY', 'EASY/INTERMEDIATE', 'INTERMEDIATE', 
                     'INTERMEDIATE/DIFFICULT', 'DIFFICULT', 
                     'VERY DIFFICULT'] )
plt.title('UT Trail Difficulty Distribution', size = 16)
plt.ylabel('Count', size = 14)
plt.xlabel('Difficulty', size = 14)
plt.xticks(rotation = 90)

plt.show()

# %% [markdown]
# The majority of trails in Arizona are rated intermediate.
