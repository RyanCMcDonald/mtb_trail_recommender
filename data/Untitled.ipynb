# %% [markdown]
# # <img src="../resources/GA.png" width="25" height="25" /> <span style="color:Blue">DSI Capstone:  MTB Trail Recommender Engine</span>
# ---
# ## <span style="color:Green">Preprocessing - Cleaning / Merging Datasets</span>
#
# #### Ryan McDonald -General Assembly
#
#
#
# ---

# %% [markdown]
# **Imports**

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# **Data Dictionary**

# %% [markdown]
# | Feature     | dType | Description                |
# |-------------|-------|----------------------------|
# | trail_URL   | str   | URL to specific trail      |
# | trail       | str   | trail name                 |
# | riding_area | str   | trail system               |
# | distance    | int   | trail distance             |
# | descent     | int   | total trail descent        |
# | climb       | int   | total trail climb          |
# | difficulty  | obj   | trail difficulty rating    |
# | coordinates | float | trailhead GPS location     |
# | popularity  | int   | trail rating (0-100)       |
# | user_URL    | str   | users trail log page       |
# | user_name   | str   | user name                  |
# | city        | str   | user hometown              |
# | trails      | str   | trails logged by user ride |
# | dist        | int   | length of user ride        |

# %% [markdown]
# ### 1. Read the Data

# %%
trail_1 = pd.read_csv('../data/Massachusetts _ Trail_00.csv')

trail_1.head()
# Out:
#                                            title_URL  \
# 0            https://www.trailforks.com/trails/1675/
# 1  https://www.trailforks.com/trails/1c-to-mentze...
# 2  https://www.trailforks.com/trails/1d-to-1c-con...
# 3  https://www.trailforks.com/trails/1d-to-1e-con...
# 4  https://www.trailforks.com/trails/1f-connector...
#
#                                             title        ridingarea  distance  \
# 0                                         1-6-7-5     Perkins Woods  1,854 ft
# 1  1C to Mentzer Conservation Trail (Cave Bypass)  Rattlesnake Hill    124 ft
# 2                              1D to 1C Connector  Rattlesnake Hill    490 ft
# 3                              1D to 1E Connector  Rattlesnake Hill    619 ft
# 4                              1F Connector Trail  Rattlesnake Hill       NaN
#
#   descent  climb                                   DifficultyRating  \
# 0   -5 ft  20 ft  \n                     Blue rate\n            ...
# 1   -3 ft    NaN  \n                     Blue rate\n            ...
# 2  -71 ft    NaN  \n                     Blue rate\n            ...
# 3   -2 ft  23 ft  \n                     Blue rate\n            ...
# 4     NaN    NaN                                                NaN
#
#                Coordinates  Local_Popularity
# 0  (42.675730, -70.966960)              90.0
# 1  (42.437550, -71.571900)              15.0
# 2  (42.438420, -71.572390)              75.0
# 3  (42.438950, -71.570290)              95.0
# 4                      NaN               5.0

# %%
trail_1.dtypes
# Out:
# title_URL            object
# title                object
# ridingarea           object
# distance             object
# descent              object
# climb                object
# DifficultyRating     object
# Coordinates          object
# Local_Popularity    float64
# dtype: object

# %%
user_1 = pd.read_csv('../data/List All Ride Logs _ Trailforks.csv')
user_1.head()
# Out:
#   created                                       username_URL        username  \
# 0  Aug 17  https://www.trailforks.com/profile/AidanVelazq...  AidanVelazquez
# 1  Mar 22        https://www.trailforks.com/profile/Simmo85/         Simmo85
# 2  Mar 22   https://www.trailforks.com/profile/EeshVentures/    EeshVentures
# 3  Mar 22      https://www.trailforks.com/profile/Springs59/       Springs59
# 4  Mar 22   https://www.trailforks.com/profile/EeshVentures/    EeshVentures
#
#         username2 State          city                trails  \
# 0  AidanVelazquez    CA     Idyllwild      Coyote Run Trail
# 1         Simmo85    FL     Melbourne       Southbank Trail
# 2    EeshVentures    ID  New Plymouth                   NaN
# 3       Springs59    ID  New Plymouth                   NaN
# 4    EeshVentures    ID  New Plymouth                   NaN
#
#                                           trails_URL  \
# 0  https://www.trailforks.com/ridelog/view/166257...
# 1  https://www.trailforks.com/ridelog/view/230456...
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                          trails_URL3           trails4  \
# 0  https://www.trailforks.com/trails/coyote-run-t...  Coyote Run Trail
# 1  https://www.trailforks.com/trails/southbank-tr...   Southbank Trail
# 2                                                NaN               NaN
# 3                                                NaN               NaN
# 4                                                NaN               NaN
#
#    trails_URL5  trails6     dist
# 0          NaN      NaN  3 miles
# 1          NaN      NaN  8 miles
# 2          NaN      NaN  2 miles
# 3          NaN      NaN  2 miles
# 4          NaN      NaN   1 mile

# %%
user_1.dtypes
# Out:
# created          object
# username_URL     object
# username         object
# username2        object
# State            object
# city             object
# trails           object
# trails_URL       object
# trails_URL3      object
# trails4          object
# trails_URL5     float64
# trails6         float64
# dist             object
# dtype: object
